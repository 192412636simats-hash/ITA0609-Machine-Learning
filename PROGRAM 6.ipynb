# %% [markdown]
# <a href="https://colab.research.google.com/github/192412636simats-hash/ITA0609-Machine-Learning/blob/main/PROGRAM%206.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#

# %%
# Restaurant Billing System

food_bill = float(input("Enter Food Bill: "))

gst = food_bill * 0.05
service = food_bill * 0.10

total = food_bill + gst + service

print("GST:", gst)
print("Service Charge:", service)
print("Total Bill:", total)
# Out:
# Enter Food Bill: 1500
# GST: 75.0
# Service Charge: 150.0
# Total Bill: 1725.0
