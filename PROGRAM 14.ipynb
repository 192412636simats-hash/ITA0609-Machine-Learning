# %% [markdown]
# <a href="https://colab.research.google.com/github/192412636simats-hash/ITA0609-Machine-Learning/blob/main/PROGRAM%2014.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Attendance Percentage Calculator

total = int(input("Enter Total Classes: "))
attended = int(input("Enter Classes Attended: "))

percentage = (attended / total) * 100

print("Attendance Percentage:", percentage)

if percentage >= 75:
    print("Eligible for Exam")
else:
    print("Not Eligible for Exam")
# Out:
# Enter Total Classes: 34
# Enter Classes Attended: 30
# Attendance Percentage: 88.23529411764706
# Eligible for Exam
