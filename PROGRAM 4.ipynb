# %% [markdown]
# <a href="https://colab.research.google.com/github/192412636simats-hash/ITA0609-Machine-Learning/blob/main/PROGRAM%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#

# %%
# ATM Cash Withdrawal System

balance = 10000
pin = 1234

user_pin = int(input("Enter PIN: "))

if user_pin == pin:
    amount = float(input("Enter withdrawal amount: "))

    if amount <= balance:
        balance = balance - amount
        print("Withdrawal Successful")
        print("Remaining Balance:", balance)
    else:
        print("Insufficient Balance")
else:
    print("Invalid PIN")
# Out:
# Enter PIN: 1234
# Enter withdrawal amount: 6000
# Withdrawal Successful
# Remaining Balance: 4000.0
