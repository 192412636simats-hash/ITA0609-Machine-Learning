# %% [markdown]
# <a href="https://colab.research.google.com/github/192412636simats-hash/ITA0609-Machine-Learning/blob/main/PROGRAM%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#

# %%
# Employee Salary Calculator

# Input employee details
name = input("Enter Employee Name: ")
basic_salary = float(input("Enter Basic Salary: "))

# Calculate deductions
pf = basic_salary * 0.12      # 12% Provident Fund
tax = basic_salary * 0.10     # 10% Tax

# Calculate gross and net salary
gross_salary = basic_salary
total_deductions = pf + tax
net_salary = gross_salary - total_deductions

# Display salary details
print("\n----- Employee Salary Details -----")
print("Employee Name :", name)
print("Basic Salary  :", basic_salary)
print("Gross Salary  :", gross_salary)
print("Provident Fund (PF) :", pf)
print("Tax           :", tax)
print("Total Deductions :", total_deductions)
print("Net Salary    :", net_salary)
# Out:
# Enter Employee Name: Jeeva
# Enter Basic Salary: 10000
#
# ----- Employee Salary Details -----
# Employee Name : Jeeva
# Basic Salary  : 10000.0
# Gross Salary  : 10000.0
# Provident Fund (PF) : 1200.0
# Tax           : 1000.0
# Total Deductions : 2200.0
# Net Salary    : 7800.0
