# %% [markdown]
# <a href="https://colab.research.google.com/github/192412636simats-hash/ITA0609-Machine-Learning/blob/main/PROGRAM%2011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#

# %%
# Fuel Cost Estimator

distance = float(input("Enter Distance (km): "))
mileage = float(input("Enter Mileage (km/l): "))
fuel_price = float(input("Enter Fuel Price per litre: "))

fuel = distance / mileage
cost = fuel * fuel_price

print("Fuel Required:", fuel, "litres")
print("Fuel Cost = ₹", cost)
# Out:
# Enter Distance (km): 30
# Enter Mileage (km/l): 20
# Enter Fuel Price per litre: 105
# Fuel Required: 1.5 litres
# Fuel Cost = ₹ 157.5
