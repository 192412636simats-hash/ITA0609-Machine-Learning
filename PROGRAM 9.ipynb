# %% [markdown]
# <a href="https://colab.research.google.com/github/192412636simats-hash/ITA0609-Machine-Learning/blob/main/PROGRAM%209.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#

# %%
# Library Fine Calculator

days = int(input("Enter Overdue Days: "))

fine = days * 5

print("Library Fine = ₹", fine)
# Out:
# Enter Overdue Days: 15
# Library Fine = ₹ 75
