# %% [markdown]
# <a href="https://colab.research.google.com/github/192412636simats-hash/ITA0609-Machine-Learning/blob/main/Program_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program 16: Online Voting Eligibility Checker

# Read age and nationality
age = int(input("Enter your age: "))
nationality = input("Enter your nationality: ")

# Check voting eligibility
if age >= 18 and nationality.lower() == "indian":
    print("Eligible to Vote")

    if age < 18 or nationality.lower() != "indian":
        print("Not Eligible to Vote")
# Out:
# Enter your age: 19
# Enter your nationality: Indian
# Eligible to Vote
