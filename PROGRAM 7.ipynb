# %% [markdown]
# <a href="https://colab.research.google.com/github/192412636simats-hash/ITA0609-Machine-Learning/blob/main/PROGRAM%207.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#

# %%
# Bank Interest Calculator

p = float(input("Enter Principal: "))
r = float(input("Enter Rate: "))
t = float(input("Enter Time (years): "))

si = (p * r * t) / 100
ci = p * ((1 + r / 100) ** t) - p

print("Simple Interest:", si)
print("Compound Interest:", ci)
# Out:
# Enter Principal: 10000
# Enter Rate: 15
# Enter Time (years): 10
# Simple Interest: 15000.0
# Compound Interest: 30455.57735707907
